# %%
import pandas.io.sql as psql
import pandas as pd
import psycopg2

# %%
connection = psycopg2.connect('postgresql://postgres:postgres@localhost:5432/project_3')
query = "SELECT * FROM pork_prices"
dataframe = psql.read_sql(query, connection)
dataframe.head(5)
# Out:
# /var/folders/x5/vxxw6g_96f337pf8r_zr_15h0000gn/T/ipykernel_17056/1863118083.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataframe = psql.read_sql(query, connection)
#           DATE  Byproduct  Gross_farm_value  Net_farm_value  Wholesale_value  \
# 0   January-70        4.3              52.3            48.0             71.2
# 1  February-70        4.7              53.9            49.2             70.4
# 2     March-70        4.8              49.6            44.8             68.0
# 3     April-70        4.3              45.9            41.6             65.2
# 4       May-70        3.7              44.9            41.2             65.2
#
#    Retail_value  Total  Farm_wholesale  Wholesale_retail
# 0          81.4   33.4            23.2              10.2
# 1          81.1   31.9            21.2              10.7
# ...

# %%
import datetime as dt

# %%
dataframe['DATE']
# Out:
# 0        January-70
# 1       February-70
# 2          March-70
# 3          April-70
# 4            May-70
#            ...
# 643       August-23
# 644    September-23
# 645      October-23
# 646     November-23
# 647     December-23
# Name: DATE, Length: 648, dtype: object

# %%
dataframe['MONTH'] = dataframe['DATE'].apply(lambda x: x.split('-')[0])
dataframe['YEAR'] = dataframe['DATE'].apply(lambda x: x.split('-')[1])

# %%
dataframe
# Out:
#              DATE  Byproduct  Gross_farm_value  Net_farm_value  \
# 0      January-70        4.3              52.3            48.0
# 1     February-70        4.7              53.9            49.2
# 2        March-70        4.8              49.6            44.8
# 3        April-70        4.3              45.9            41.6
# 4          May-70        3.7              44.9            41.2
# ..            ...        ...               ...             ...
# 643     August-23       10.3             133.7           123.4
# 644  September-23        9.7             116.7           107.0
# 645    October-23        9.9             108.6            98.7
# 646   November-23       10.0             100.8            90.8
# 647   December-23        8.5              91.1            82.6
#
#      Wholesale_value  Retail_value  Total  Farm_wholesale  Wholesale_retail  \
# 0               71.2          81.4   33.4            23.2              10.2
# ...

# %%
# Out:
# /var/folders/x5/vxxw6g_96f337pf8r_zr_15h0000gn/T/ipykernel_17056/3228382804.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataframe['DATE'] = pd.to_datetime(dataframe.DATE)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File parsing.pyx:681, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 dataframe['DATE'] = pd.to_datetime(dataframe.DATE)
#
# ...

# %%
dataframe['DATE1'] = dataframe['DATE'].dt.strftime('%B-%y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dataframe['DATE1'] = dataframe['DATE'].dt.strftime('%B-%y')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...
